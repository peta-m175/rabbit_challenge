# %% [markdown]
# <a href="https://colab.research.google.com/github/peta-m175/rabbit_challenge/blob/master/deep_learning/day2/concept_of_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 畳み込みニューラルネットワークの概念

# %% [markdown]
# ## 畳み込み層

# %% [markdown]
# 畳み込み層では、画像の場合、縦、横、チャンネルの3次元のデータをそのまま学習し、次に伝えることができる。
# - 結論:3次元の空間情報も学習できるような層が畳み込み層である。

# %% [markdown]
# ### バイアス

# %% [markdown]
# ![Screenshot from 2020-12-20 23-18-58.png](data:image/png;base64,...)

# %% [markdown]
# ### パディング

# %% [markdown]
# ![Screenshot from 2020-12-20 23-19-34.png](data:image/png;base64,...)

# %% [markdown]
# ### ストライド

# %% [markdown]
# ![Screenshot from 2020-12-20 23-20-17.png](data:image/png;base64,...)

# %% [markdown]
# ### チャンネル

# %% [markdown]
# ![Screenshot from 2020-12-20 23-20-43.png](data:image/png;base64,...)

# %% [markdown]
# ## プーリング層

# %% [markdown]
# ![Screenshot from 2020-12-20 23-21-37.png](data:image/png;base64,...)

# %% [markdown]
# ## 確認テスト

# %% [markdown]
# ### P.100

# %% [markdown]
# - Q: サイズ6×6の入力画像を、サイズ2×2のフィルタで畳み込んだ時の出力画像のサイズを答えよ。なおストライドとパディングは1とする。
# - A: 7x7
# $$
# OH=\frac{H+2P-FH}{S}+1=\frac{6+2\cdot 1-2}{1}+1=7 \\
# OW=\frac{W+2P-FH}{S}+1=\frac{6+2\cdot 1-2}{1}+1=7
# $$

# %% [markdown]
# ## 演習

# %% [markdown]
# https://colab.research.google.com/github/peta-m175/rabbit_challenge/blob/master/deep_learning/day2/exercises/2_6_simple_convolution_network.ipynb
