# %% [markdown]
# <a href="https://colab.research.google.com/github/peta-m175/rabbit_challenge/blob/master/deep_learning/day2/overtraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 過学習

# %% [markdown]
# ## Weight decay(荷重減衰)

# %% [markdown]
# - 過学習の原因
#   - 重みが大きい値をとることで、過学習が発生することがある。
#     - 学習させていくと、重みにばらつきが発生する。重みが大きい値は、学習において重要な値であり、重みが大きいと過学習が起こる
#
# - 過学習の解決策
#   - 誤差に対して、正則化項を加算することで、重みを抑制する
#     - 過学習がおこりそうな重みの大きさ以下で重みをコントロールし、かつ重みの大きさにばらつきを出す必要がある。

# %% [markdown]
# ## L1正則化、L2正則化

# %% [markdown]
# 誤差関数に、$p$ノルムを加える
# $$
# ||x||_p = (|x_1|^p+\dots+|x|^p)^{\frac{1}{p}} \\
# E_n(w)+\frac{1}{p}\lambda||x||_p \\
# $$
# ```
# np.sum(np.abs(network.params['W' + str(idx)]))
# weight_decay+= weight_decay_lambda*np.sum(np.abs(network.params['W' + str(idx)]))
# loss = network.loss(x_batch, d_batch) + weight_decay数式PythonS3)-1日本語67
# ```
# - $p=1$
#   - L1正則化
# - $p=2$
#   - L2正則化

# %% [markdown]
# ## ドロップアウト

# %% [markdown]
# ランダムにノードを削除して学習させること
#
# - メリット
#   - データ量を変化させずに、異なるモデルを学習させていると解釈できる

# %% [markdown]
# ## 確認テスト

# %% [markdown]
# ## P.68

# %% [markdown]
# - Q: 下図について、L1正則化を表しているグラフはどちらか答えよ。
# - A:
# ![image_lasso_ridge.png](data:image/png;base64,...)
#   - L1:計算リソースをカット
#   - L2:精度向上

# %% [markdown]
# ## 演習

# %% [markdown]
# https://colab.research.google.com/github/peta-m175/rabbit_challenge/blob/master/deep_learning/day2/exercises/2_5_overfiting.ipynb
