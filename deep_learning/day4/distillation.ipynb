# %% [markdown]
# <a href="https://colab.research.google.com/github/peta-m175/rabbit_challenge/blob/master/deep_learning/day4/distillation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 蒸留

# %% [markdown]
# 精度の高いモデルはニューロンの規模が大きくなってくる\
# -> 推論に多くのメモリと演算処理が必要\
# ->規模の大きなモデルの知識を使い軽量なモデルを作成する

# %% [markdown]
# ## モデルの簡約化

# %% [markdown]
# ![Screenshot from 2020-12-31 02-34-19.png](data:image/png;base64,...)

# %% [markdown]
# 知識の継承により、軽量でありながら複雑なモデルに匹敵する精度のモデルを得ることが期待できる

# %% [markdown]
# ## 教師モデルと生徒モデル

# %% [markdown]
# - 教師モデル
#   - 予測精度の高い、複雑なモデルやアンサンブルされたモデル
# - 生徒モデル
#   - 教師モデルをもとに作られる軽量なモデル
#
# https://arxiv.org/abs/1503.02531

# %% [markdown]
# 教師モデルの重みを固定し生徒モデルの重みを更新していく\
# 誤差は教師モデルと生徒モデルのそれぞれの誤差を使い重みを更新していく

# %% [markdown]
# ![Screenshot from 2020-12-31 02-36-54.png](data:image/png;base64,...)

# %% [markdown]
# ## 利点

# %% [markdown]
# 少ない学習回数でより精度の良いモデルを作成することができている
#
# https://arxiv.org/abs/1412.6550
