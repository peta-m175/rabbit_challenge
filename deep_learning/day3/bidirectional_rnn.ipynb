# %% [markdown]
# <a href="https://colab.research.google.com/github/peta-m175/rabbit_challenge/blob/master/deep_learning/day3/bidirectional_rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 双方向RNN

# %% [markdown]
# 過去の情報だけでなく、未来の情報を加味することで、精度を向上させるためのモデル
#
# 実用例\
# 文章の推敲や、機械翻訳等

# %% [markdown]
# ![Screenshot from 2020-12-26 17-05-38.png](data:image/png;base64,...)
